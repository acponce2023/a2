# %% [markdown]
# <a href="https://colab.research.google.com/github/acponce2023/a2/blob/main/ejemplo_f20231103.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Muestra de glosario, terapia ocupacional

# %%
import json
#from pandas import read_csv
#import pandas as pd

# Los ficheros deben estar cargados en la sesión de Colab para que funcione esto

raw_data = json.loads(open("raw_epo_11_oct_ger.json").read())
##gold_data = pd.read_csv("Glossary_DEU ENG_11 Oct_CSV.csv")
##file_content = open("Glossary_DEU ENG_11 Oct.json").read()
gold_data = json.loads(open("Glossary_DEU ENG_11 Oct.json").read())

print(raw_data)
print(gold_data)
##print(gold_data.shape)
##print(gold_data.head(100))


raw_terms = [term['forms']['ger'][0]['text'] for term in raw_data]
gold_terms = [term [' HDF-, MDF-, USB-, Span- oder Sperrholzplatten']for term in gold_data]

print("Términos extraídos:", len(raw_terms))
print(raw_terms)

print("Términos válidos:", len(gold_terms))
print(gold_terms)

lista_comun_ger = set.intersection(set(raw_terms), set(gold_terms))
print ("Terminos en comun ger:", len(lista_comun_ger))
print(lista_comun_ger)
# Matriz Confusion
# Definimos el listado inicial como A y el listado final como B, los valores de la matriz los podemos razonar de la siguiente forma:
# A :terminos a filtrar  SPA ; B: Términos filtrados y lematizados
#TP: la intersección de A y B
#FP: los valores de A no contenidos en B
#FN: los valores de B no contenidos en A
#TN: ¿?

# TP      FN
# FP      TN
#----------->
# 51   0
# 485  0

print("PRECISION = TP /(TP + FP) =" , 51/536)
# Out:
# [{'forms': {'eng': [], 'ger': [{'origin': 'TBXTools/spacy', 'text': 'Glanzgrad', 'type': 'extracted'}]}, 'id': 'd56c2034-0f19-496a-9278-0cefd49a3215'}, {'forms': {'eng': [], 'ger': [{'origin': 'TBXTools/spacy', 'text': 'Schutzschicht', 'type': 'extracted'}]}, 'id': '44c9b8b1-f9ee-41b3-bb25-d002670c8642'}, {'forms': {'eng': [], 'ger': [{'origin': 'TBXTools/spacy', 'text': 'Beschichtung', 'type': 'extracted'}]}, 'id': 'eadc117b-104f-439f-a5ad-3c0b31fa0ceb'}, {'forms': {'eng': [], 'ger': [{'origin': 'TBXTools/spacy', 'text': 'Glanzgrade', 'type': 'extracted'}]}, 'id': '68710a39-bd2d-4f10-bb78-4870f8057d09'}, {'forms': {'eng': [], 'ger': [{'origin': 'TBXTools/spacy', 'text': 'Beschichtungen', 'type': 'extracted'}]}, 'id': '0e96d400-0cfc-4f6f-a084-83e141087c4b'}, {'forms': {'eng': [], 'ger': [{'origin': 'TBXTools/spacy', 'text': 'metallische Beschichtung', 'type': 'extracted'}]}, 'id': '466f9fc2-c64c-48ea-9d06-2d90943dc80e'}, {'forms': {'eng': [], 'ger': [{'origin': 'TBXTools/spacy', 'text': 'Pressbleche', 'type': 'extracted'}]}, 'id': 'ea0eaa83-da62-40e2-8de7-cafcfb514e84'}, {'forms': {'eng': [], 'ger': [{'origin': 'TBXTools/spacy', 'text': 'strukturierten Oberfläche', 'type': 'extracted'}]}, 'id': '73572b1d-7337-437a-8b74-26cb83e47ba7'}, {'forms': {'eng': [], 'ger': [{'origin': 'TBXTools/spacy', 'text': 'Drucktechnik', 'type': 'extracted'}]}, 'id': '920422a7-51ad-44b2-bb83-327056f27abd'}, {'forms': {'eng': [], 'ger': [{'origin': 'TBXTools/spacy', 'text': 'korrodierten Abschnitte', 'type': 'extracted'}]}, 'id': 'f81ea5bd-b0c8-4acd-961d-0f17fe897649'}, {'forms': {'eng': [], 'ger': [{'origin': 'TBXTools/spacy', 'text': 'Mattierungsmittel', 'type': 'extracted'}]}, 'id': 'b7116669-3d9b-49b6-aa44-03fa519015de'}, {'forms': {'eng': [], 'ger': [{'origin': 'TBXTools/spacy', 'text': 'Streitpatent', 'type': 'extracted'}]}, 'id': 'e4fab5ac-ef60-43a0-95dc-bdf62943b2f8'}, {'forms': {'eng': [], 'ger': [{'origin': 'TBXTools/spacy', 'text': 'Metallschicht', 'type': 'extracted'}]}, 'id': '70db8f7d-46cf-4cc9-b406-efe6f2da5e2c'}, {'forms': {'eng': [], 'ger': [{'origin': 'TBXTools/spacy', 'text': 'Gussform', 'type': 'extracted'}]}, 'id': 'd8a6b04d-9742-4f20-a499-1e965cf2705b'}, {'forms': {'eng': [], 'ger': [{'origin': 'TBXTools/spacy', 'text': 'Rechtsanwaltsgesellschaft', 'type': 'extracted'}]}, 'id': '9cadf780-e756-40df-a22f-58dea934b327'}, {'forms': {'eng': [], 'ger': [{'origin': 'TBXTools/spacy', 'text': 'Verchromung', 'type': 'extracted'}]}, 'id': '5a4e556f-9a6d-4066-b846-045a5ee7a848'}, {'forms': {'eng': [], 'ger': [{'origin': 'TBXTools/spacy', 'text': 
}, {' HDF-, MDF-, USB-, Span- oder Sperrholzplatten': 'Einbrennen', 'HDF, MDF, USB, chipboard or plywood boards': 'burn-in'}, {' HDF-, MDF-, USB-, Span- oder Sperrholzplatten': 'Elektropolieren', 'HDF, MDF, USB, chipboard or plywood boards': 'electrolytic polishing'}, {' HDF-, MDF-, USB-, Span- oder Sperrholzplatten': 'Endlosbänder', 'HDF, MDF, USB, chipboard or plywood boards': 'continuous belts'}, {' HDF-, MDF-, USB-, Span- oder Sperrholzplatten': 'energetischer Strahl', 'HDF, MDF, USB, chipboard or plywood boards': 'energetic beam'}, {' HDF-, MDF-, USB-, Span- oder Sperrholzplatten': 'Energiestrahl', 'HDF, MDF, USB, chipboard or plywood boards': 'energy beam'}, {' HDF-, MDF ...
# Términos extraídos: 536
# ['Glanzgrad', 'Schutzschicht', 'Beschichtung', 'Glanzgrade', 'Beschichtungen', 'metallische Beschichtung', 'Pressbleche', 'strukturierten Oberfläche', 'Drucktechnik', 'korrodierten Abschnitte', 'Mattierungsmittel', 'Streitpatent', 'Metallschicht', 'Gussform', 'Rechtsanwaltsgesellschaft', 'Verchromung', 'unterschiedliche Glanzgrade', 'Werkstoffplatten', 'Ätzen', 'strukturierte Oberfläche', 'Burger Rechtsanwaltsgesellschaft', 'korrodierte Abschnitte', 'Holzpore', 'digitalen Drucktechnik', 'abweichenden Glanzgrad', 'versehenen Oberfläche', 'Prägewerkzeuge', 'Metallgussform', 'metallischen Beschichtung', 'metallischen Beschichtungen', 'Ätzmittel', 'partielle Bereiche', 'höheren Glanzgrad', 'vorhergehenden Ansprüche', 'Presswerkzeuge', 'Fotoschicht', 'Metallschichten', 'Rheinische GmbH', 'Oberflächenstrukturierung', 'Ätzung', 'erneutes Auftragen', 'bestimmten Glanzgrad', 'passgenauen Maske', 'unterschiedlichen Glanzgraden', 'zweiten Schutzschicht', 'chemische Nachbehandlung', 'liegenden Bereiche', 'Patentansprüche', 'Arbeitsschritten', 'ausgewählten Bereichen', 'zweite Schutzschicht', 'ersten Beschichtung', 'Verchromen', 'Auftragung', 'Umschmelzen', 'Oberflächenbehandlung', 'Anmelder', 'Mattätzen', 'Datum Blatt', 'ersten Maske', 'korrodierten Abschnitten', 'Endlosband', 'Pressblechen', 'Ätzvorgänge', 'Ätzverfahren', 'Strukturtiefe', 'gesamte Oberfläche', 'Anmeldetag', 'erhabenen Bereiche', 'Makrostruktur', 'dekoratives Motiv', 'Presszeit', 'Verpressung', 'Sandstrahlen', 'Maskenauftragung', 'metallische Beschichtungen', 'bearbeitete Oberfläche', 'unterschiedlichen Glanzgrad', 'abweichenden Glanzgraden', 'Strukturgrund', 'vorbereiteten Oberfläche', 'Metallbeschichtungen', 'polierten Oberfläche', 'weitere metallische Beschichtung', 'liegende Bereiche', 'abgedeckten Bereiche', 'unterschiedlichen Grad', 'ersten Schutzschicht', 'Viersen', 'Patentanspruch', 'Ätzflüssigkeit', 'Oberflächenätzung', 'Nachbehandlungen', 'Glanzgradeinstellung', 'perspektivischen Ansicht', 'Tiefenstruktur', 'ersten metallischen Beschichtung', 'Ausgangsgussform', 'erfindungsgemäße Verfahren', 'erhaltenen Oberfläche', 'Stahlblech', 'Haptik', 'unterschiedlicher Glanzgrade', 'dekorative Motiv', 'Mattierungsmaterial', 'Oberflächenseite', 'verchromte Oberfläche', 'strukturierten Oberflächenseite', 'energetischen Strahl', 'Holzwerkstoffplatten', 'Reproduzierbarkeit', 'weitere unterschiedliche Glanzgrade', 'erneute metallische Beschichtung', 'einziges konkretes Beispiel', 'Elektropolieren', 'HOFFMANN EITLE', 'besondere Vorteil', 'Pressblechoberfläche', 'nachfolgende Oberflächenbehandlung', 'vorhandene Strukturen', 'vergrößerten Seitenansicht', 'verchromten Oberfläche', 'Bereich Bereich', 'identische Masken', 'besseren Haftung', 'gewünschten Struktur', 'zweiten passgenauen Maske', 'energetische Strahlung', 'digitale Drucktechnik', 'weiterer Ausgestaltung', 'verwendete Mattierungsmaterial', 'chemischen Nachbehandlungen', 'angestrebte Lösung', 'erfolgter Verpressung', 'erste metallische Beschichtung', 'erste Maske', 'Überdeckung', 'konkretes Beispiel', 'erneutes chemisches Bearbeiten', 'Prägnat', 'Hartchromschicht', 'weitere metallische Beschichtungen', 'Hartverchromung', 'Anmeldenummer', 'unterschiedlichen Glanzgrade', 'erhabenen Flächen', 'dritten passgenauen Maske', 'weiteren Arbeitsschritten', 'Verschleißfestigkeit', 'Patentdokument', 'Europäischen Patentamts', 'zweiten Maske', 'korrodierten Bereiche', 'vorliegenden Erfindung', 'Oberflächenstrukturen', 'erfindungsgemäßen Verfahren', 'partiellen Bereiche', 'Holzmaserung', 'naturgetreue Nachbildung', 'Bereichen weitere unterschiedliche', 'Anmeldedatum', 'anderen Glanzgrad', 'unterschiedliche Schattierungen', 'versehenen verchromten Oberfläche', 'gewünschten Glanzgrad', 'erste Beschichtung', 'bearbeiteten Oberfläche', 'genannten Schritte', 'gewünschten Vernetzungsgrad', 'Holzstruktur', 'gereinigten Oberfläche', 'unterschiedlicher Glanzgrad', 'Nickelschicht', 'metallisches Pressblech', 'aktivierten Oberfläche', 'unkorrodie ...
# Términos válidos: 152
# ['Abriebfestigkeit', 'aktivierten Oberfläche', 'Arbeitsgang', 'Ätzen', 'Ätzmittel', 'ätzresistenten Maske ', 'Ätzvorgänge', 'auf die Platte geprägt', 'Ausgangsblech', 'Ausgangsgussform', 'Bauplatten', 'Belichtung', 'Beschichtete Spanplatte', 'Blech', 'Bodenbelägen', 'chromsäurebeständigen Material ', 'Chromschicht „unergründlich“', 'dekoratives Kunststofflaminat', 'dekoratives Motiv', 'Dekorpanel', 'Druckkopf', 'Duroplastharze', 'Düsenkopf', 'Echtholzcharakters', 'Einbrennen', 'Elektropolieren', 'Endlosbänder', 'energetischer Strahl', 'Energiestrahl', 'erhabene vs. tiefer liegende Bereiche', 'erhabenen Bereiche', 'ersten Schutzschicht', 'feinkörnig', 'Fingerabdrücke', 'Flanken der Täler', 'Formen in der Gussform', 'Fotoätzung', 'Fotoschicht auftragen', 'freiliegende Bereiche', 'gebirgsähnliche Oberfläche', 'Gesteinsnachbildung', 'glänzend-matte Nuancen', 'Glanzgrad', 'Glanzgradveränderung', 'Grundmaterial', 'halzgetränkte Papierblätter', 'Hartverchromung', 'Harzfilm', 'Heizpressenanlagen', 'Hochglanzverchromung', 'Höhen', 'Höhenprofils', 'Holzdekor', 'Holzmaserung', 'Holzporen', 'Holzwerkstoff-platte verpresst', 'Holzwerkstoffplatten', 'Kantenbereiches', 'korrodierte Abschnitte', 'Korundmaterialien', 'Maske', 'maskierten Oberfläche', 'Matrix aufgetragen', 'matt glänzend', 'Mattätzen', 'Mattglanz', 'Mattglanzverchromung', 'Mattierungsmittel', 'Mattierungsmittel', 'mechanisch oder elektrolytisch entfernt ', 'mechanische Polierung', 'Melamin-, Phenol- oder Melamin-IHarnstoff-harze', 'Melaminharz getränkten Filmen/Papieren/Dekoren', 'Messing- oder Kupferschicht ', 'Metallbeschichtung', 'Metallgussform', 'metallischen Pressblech', 'Metallschicht', 'mit einem Prägeblech ummantelt', 'Muster', 'Nachbehandlung', 'Nachstrukturierung', 'Näpfchen', 'naturgetreue Oberfläche ', 'natürlich gewachsener Holzwerkstoff ', 'Natursteinoberfläche eines geograﬁschen Musters', 'Negativabdruck', 'nicht korrodierten Abschnitten', 'Nickelschicht', 'Nutzfahrzeugböden', 'Oberflache', 'Oberflächenrauigkeit', 'Oberflächenstruktur', 'Oberflächenvergütungen', 'Overlaypapier', 'Paneelen für den Innenausbau', 'passgenauen Maske', 'perlförmige oder feinstreifige Oberflächenstrukturen', 'Platten- oder Bandmaterial ', 'polierbeständig', 'Polieren', 'polierten Oberfläche', 'Polykondensation', 'Prägewalze', 'Prägewerkzeug', 'Prägnat', 'Pressblech', 'Pressspan', 'Pressspanplatten', 'Presswerkzeug', 'Presswerkzeugoberfläche', 'Profiltäler', 'Rauten', 'Riffelungen', 'Rundätzung', 'Rutschfestigkeit', 'Sandstrahlen', 'schichtweisen Aufbau der Erhebungen ', 'Schutzschicht', 'Siebdruckverfahren', 'Spanplatte', 'Sprühkopf', 'Strahlgut', 'strukturierten Oberflache', 'strukturkonforme Überdeckung ', 'Strukturtiefe', 'Tälern', 'Tiefenätzung', 'tiefer liegenden Bereiche', 'Trenneigenschaften', 'Türblätter', 'Türrahmen', 'überbeschichten', 'Überlappung aus ästhetischen Gesichtspunkten gewünscht', 'Umschmelzen', 'unterschiedlichen Grad an Glanz', 'UV-Lack ', 'Verchromen', 'Verchromung', 'Verchromungsschicht', 'Verdampfung', 'Vernetzungsgrad der Harze', 'verpressen', 'Verschleißfestigkeit', 'vollflächig', 'vollﬂächige und/oder partielle ', 'Wachsauftrag', 'Wandverkleidungen', 'Werkstoffplatte', 'Werkstoffplatten', 'zweiten Schutzschicht', 'Zylinder']
# Terminos en comun ger: 51
# {'Oberflächenrauigkeit', 'Ausgangsgussform', 'Ätzen', 'Hartverchromung', 'Rauten', 'Mattierungsmittel', 'Näpfchen', 'Ätzmittel', 'Ätzvorgänge', 'Glanzgradveränderung', 'Strukturtiefe', 'Metallbeschichtung', 'zweiten Schutzschicht', 'Hochglanzverchromung', 'gebirgsähnliche Oberfläche', 'Rundätzung', 'Duroplastharze', 'Elektropolieren', 'Prägnat', 'Glanzgrad', 'Heizpressenanlagen', 'Sandstrahlen', 'Schutzschicht', 'Metallschicht', 'Verchromung', 'Verchromen', 'Holzwerkstoffplatten', 'Energiestrahl', 'Siebdruckverfahren', 'aktivierten Oberfläche', 'Riffelungen', 'polierten Oberfläche', 'Umschmelzen', 'ersten Schutzschicht', 'dekoratives Motiv', 'Mattätzen', 'mechanische Polierung', 'passgenauen Maske', 'Werkstoffplatten', 'erhabenen Bereiche', 'Verchromungsschicht', 'Holzmaserung', 'Mattglanzverchromung', 'Metallgussform', 'Einbrennen', 'Abriebfestigkeit', 'Presswerkzeugoberfläche', 'korrodierte Abschnitte', 'maskierten Oberfläche', 'Verschleißfestigkeit', 'Nickelschicht'}
# PRECISION = TP /(TP + FP) = 0.09514925373134328
